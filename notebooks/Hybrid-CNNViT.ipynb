# %% [markdown]
# - actual - 94.09
# - change projection_dim to 64 to 128 - 94.12
# - Reduce patch size to 8×8 - 94.12
# - Reduce patch size to 4X4 -94.29

# %% [markdown]
# # 1. Import the Libraries

# %%
import os
import shutil
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dropout, Flatten, Dense, Input, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import StratifiedKFold
# Out:
# 2025-10-27 00:13:20.994413: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-27 00:13:20.994455: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-27 00:13:20.994494: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
print("Available GPUs:", gpus)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # 2. Load Data

# %% [markdown]
# ## 2.1 Without Augmentation

# %%
# Paths
original_data_dir = "../data/external/1. Brain Tumor MRI Dataset(Kaggle)"  # Path to the original dataset
split_data_dir = "/split/BT/splitCV2"  # Directory to store split datasets
if not os.path.exists(split_data_dir):
    os.makedirs(split_data_dir)

# Function to clear directories
def clear_directory(directory):
    if os.path.exists(directory):
        shutil.rmtree(directory)  # Remove the entire directory
    os.makedirs(directory, exist_ok=True)  # Recreate the directory

# Clear train, val, and test directories before splitting data
clear_directory(split_data_dir)

# Function to split the dataset into 10 folds and store them in `splitSSWE`
def prepare_splits(data_dir, split_dir, n_splits=10):
    if not os.path.exists(split_dir):
        os.makedirs(split_dir)

    # Get class names (only directories)
    class_names = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
    all_images = []

    # Collect all image paths and labels
    for label, class_name in enumerate(class_names):  # label is an integer index
        class_dir = os.path.join(data_dir, class_name)
        for img_file in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_file)
            if os.path.isfile(img_path):  # Ensure it's a file, not a directory or system file
                all_images.append((img_path, int(label)))  # Store integer label

    all_images = np.array(all_images, dtype=object)  # Ensure proper dtype for mixed types
    #np.random.shuffle(all_images)

    # Create KFold splits
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    fold_idx = 0
    for train_idx, test_idx in kf.split(all_images):
        fold_dir = os.path.join(split_dir, f"fold_{fold_idx}")
        os.makedirs(fold_dir, exist_ok=True)
        train_dir = os.path.join(fold_dir, "train")
        test_dir = os.path.join(fold_dir, "test")
        os.makedirs(train_dir, exist_ok=True)
        os.makedirs(test_dir, exist_ok=True)

        # Copy training data
        for idx in train_idx:
            src, label = all_images[idx]
            class_name = class_names[label]  # Map integer label back to class name
            dest_dir = os.path.join(train_dir, class_name)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(src, dest_dir)

        # Copy testing data
        for idx in test_idx:
            src, label = all_images[idx]
            class_name = class_names[label]  # Map integer label back to class name
            dest_dir = os.path.join(test_dir, class_name)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(src, dest_dir)

        fold_idx += 1


# Prepare splits (only needed once)
prepare_splits(original_data_dir, split_data_dir)

# %% [markdown]
# # 3. Initialize the Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers

# ===== Your CNN Backbone (Code 2, stabilized) =====
def deep_cnn_backbone(input_shape=(168,168,3), num_classes=4):
    model = models.Sequential(name="DeepCNN")
    model.add(layers.Conv2D(32, 3, padding='same', kernel_initializer='he_normal', input_shape=input_shape))
    model.add(layers.LeakyReLU(alpha=0.01))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, 3, padding='same', kernel_initializer='he_normal'))
    model.add(layers.LeakyReLU(alpha=0.01))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, 3, padding='same', kernel_initializer='he_normal'))
    model.add(layers.LeakyReLU(alpha=0.01))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(256, 3, padding='same', kernel_initializer='he_normal'))
    model.add(layers.LeakyReLU(alpha=0.01))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(256, 3, padding='same', kernel_initializer='he_normal'))
    model.add(layers.LeakyReLU(alpha=0.01))
    model.add(layers.MaxPooling2D((2, 2)))

    # you can keep adding more convs safely
    return model


# ===== Patchify CNN Features =====
class PatchExtract(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1,1,1,1],
            padding="VALID"
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches


class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(projection_dim)
        self.pos_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patches) + self.pos_embedding(positions)
        return encoded


# ===== ViT Encoder =====
def vit_encoder(num_patches, projection_dim, transformer_layers=4, num_heads=4, mlp_dim=64):
    """Weaker ViT encoder"""
    inputs = layers.Input(shape=(num_patches, projection_dim))
    x = inputs
    for _ in range(transformer_layers):  # only 1 transformer layer
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)(x1, x1)
        x2 = layers.Add()([x, attn])

        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        mlp = layers.Dense(mlp_dim, activation=tf.nn.gelu, kernel_initializer='he_normal')(x3)
        mlp = layers.Dense(projection_dim, kernel_initializer='he_normal')(mlp)
        x = layers.Add()([x2, mlp])

    outputs = layers.LayerNormalization(epsilon=1e-6)(x)
    return models.Model(inputs, outputs, name="ViTEncoder")


# ===== Hybrid Model =====
def hybrid_cnn_vit(input_shape=(168,168,3), num_classes=4, patch_size=5, projection_dim=64):
    inputs = layers.Input(shape=input_shape)

    # CNN backbone
    cnn_backbone = deep_cnn_backbone(input_shape)
    feature_map = cnn_backbone(inputs)

    # CNN branch (direct global pooling)
    cnn_rep = layers.GlobalAveragePooling2D()(feature_map)
    cnn_rep = layers.Dense(512, activation=tf.nn.gelu)(cnn_rep)
    cnn_rep = layers.Dropout(0.3)(cnn_rep)

    # ViT branch (weaker)
    patches = PatchExtract(patch_size)(feature_map)
    H, W = feature_map.shape[1], feature_map.shape[2]
    num_patches = (H // patch_size) * (W // patch_size)
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)
    vit_block = vit_encoder(num_patches, projection_dim)
    vit_out = vit_block(encoded_patches)
    vit_rep = layers.GlobalAveragePooling1D()(vit_out)
    vit_rep = layers.Dense(64, activation=tf.nn.gelu)(vit_rep)
    vit_rep = layers.Dropout(0.2)(vit_rep)

    # 🔹 Fusion (CNN stronger, ViT weaker)
    fused = layers.Concatenate()([cnn_rep, vit_rep])
    fused = layers.Dense(256, activation=tf.nn.gelu)(fused)
    fused = layers.Dense(128, activation=tf.nn.gelu)(fused)
    # fused = layers.Dropout(0.4)(fused)

    outputs = layers.Dense(num_classes, activation='softmax')(fused)

    return models.Model(inputs, outputs, name="HybridCNNViT")


# ===== Build =====
model = hybrid_cnn_vit(input_shape=(168,168,3), num_classes=4)
model.summary()
# Out:
# Model: "HybridCNNViT"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 168, 168, 3)]        0         []
#
#  DeepCNN (Sequential)        (None, 5, 5, 256)            978496    ['input_1[0][0]']
#
#  patch_extract (PatchExtrac  (None, None, 6400)           0         ['DeepCNN[0][0]']
#  t)
#
#  patch_encoder (PatchEncode  (None, None, 64)             409728    ['patch_extract[0][0]']
#  r)
#
#  ViTEncoder (Functional)     (None, 1, 64)                299904    ['patch_encoder[0][0]']
#
#  global_average_pooling2d (  (None, 256)                  0         ['DeepCNN[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling1d (  (None, 64)                   0         ['ViTEncoder[0][0]']
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 512)                  131584    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_10 (Dense)            (None, 64)                   4160      ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['dense_10[0][0]']
#
#  concatenate (Concatenate)   (None, 576)                  0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_11 (Dense)            (None, 256)                  147712    ['concatenate[0][0]']
#
#  dense_12 (Dense)            (None, 128)                  32896     ['dense_11[0][0]']
#
#  dense_13 (Dense)            (None, 4)                    516       ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 2004996 (7.65 MB)
# Trainable params: 2004996 (7.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # 4. Model Training - Cross Fold Validation

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Perform 10-fold cross-validation
n_splits = 10
all_y_true = []  # To store true labels from all folds
all_y_pred = []  # To store predictions from all folds
fold_accuracies = []

for fold_idx in range(n_splits):
    print(f"Training Fold {fold_idx + 1}/{n_splits}")
    fold_dir = os.path.join(split_data_dir, f"fold_{fold_idx}")

    train_dir = os.path.join(fold_dir, "train")
    test_dir = os.path.join(fold_dir, "test")

    # Image Data Generators for train and test
    train_datagen = ImageDataGenerator(
        rescale=1.0/255.0,
        # Add custom augmentations here
        horizontal_flip=True,
        rotation_range=2,  # Random rotation within 2 degrees
        brightness_range=[0.8, 1.2],  # Random contrast (brightness scaling)
        zoom_range=[0.95, 1.05],  # Random zoom between 95% and 105%
        width_shift_range=0.01,  # Random horizontal shift
        height_shift_range=0.01,  # Random vertical shift
    )
    test_datagen = ImageDataGenerator(rescale=1.0/255.0)

    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(168, 168),
        batch_size=32,
        class_mode='categorical'
    )
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(168, 168),
        batch_size=32,
        class_mode='categorical',
        shuffle=False
    )

    # Create the model
    model = hybrid_cnn_vit(input_shape=(168, 168, 3), num_classes=4)

    # ✅ Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-5, clipnorm=1.0),
        loss='categorical_crossentropy',  # use 'sparse_categorical_crossentropy' if labels are integers
        metrics=['accuracy']
    )

    # Define callbacks
    callbacks = [
        EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True),
        ModelCheckpoint(filepath=os.path.join(split_data_dir, f"best_model_fold_{fold_idx}.h5"), save_best_only=True)
    ]
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)


    # Train the model
    history = model.fit(
        train_generator,
        epochs=100,
        validation_data=test_generator,
        callbacks=[callbacks, lr_scheduler]
    )

    # Predict on the test set
    test_generator.reset()
    y_pred_prob = model.predict(test_generator)  # Get probabilities or logits
    y_pred = np.argmax(y_pred_prob, axis=1)  # Get the predicted class indices
    y_true = test_generator.classes  # True labels

    # Collect results for final classification report
    all_y_true.extend(y_true)
    all_y_pred.extend(y_pred_prob)

    # Calculate and store fold accuracy
    accuracy = accuracy_score(y_true, y_pred)
    fold_accuracies.append(accuracy)
    print(f"Accuracy for Fold {fold_idx + 1}: {accuracy:.4f}")
# Out:
# Training Fold 1/10
# Found 6320 images belonging to 4 classes.
# Found 703 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - 53s 192ms/step - loss: 0.9120 - accuracy: 0.6016 - val_loss: 1.0308 - val_accuracy: 0.6202 - lr: 0.0010
# Epoch 2/100
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 37s 189ms/step - loss: 0.6101 - accuracy: 0.7456 - val_loss: 0.8801 - val_accuracy: 0.6586 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.5132 - accuracy: 0.7913 - val_loss: 0.4399 - val_accuracy: 0.8364 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.4305 - accuracy: 0.8283 - val_loss: 0.4781 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.3658 - accuracy: 0.8565 - val_loss: 0.6844 - val_accuracy: 0.7539 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.2952 - accuracy: 0.8829 - val_loss: 0.2457 - val_accuracy: 0.9047 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.2432 - accuracy: 0.9068 - val_loss: 0.3509 - val_accuracy: 0.8649 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2237 - accuracy: 0.9128 - val_loss: 0.2792 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1965 - accuracy: 0.9234 - val_loss: 0.1859 - val_accuracy: 0.9289 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1509 - accuracy: 0.9430 - val_loss: 0.2000 - val_accuracy: 0.9275 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1361 - accuracy: 0.9519 - val_loss: 0.1169 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.1032 - accuracy: 0.9620 - val_loss: 0.1697 - val_accuracy: 0.9346 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0933 - accuracy: 0.9653 - val_loss: 0.1764 - val_accuracy: 0.9531 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0853 - accuracy: 0.9663 - val_loss: 0.1704 - val_accuracy: 0.9417 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0689 - accuracy: 0.9761 - val_loss: 0.0646 - val_accuracy: 0.9858 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0646 - accuracy: 0.9785 - val_loss: 0.0810 - val_accuracy: 0.9772 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0656 - accuracy: 0.9769 - val_loss: 0.2292 - val_accuracy: 0.9459 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0531 - accuracy: 0.9840 - val_loss: 0.2427 - val_accuracy: 0.9132 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.0651 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0535 - accuracy: 0.9816 - val_loss: 0.0600 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0402 - accuracy: 0.9866 - val_loss: 0.0701 - val_accuracy: 0.9801 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0480 - accuracy: 0.9845 - val_loss: 0.2317 - val_accuracy: 0.9431 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0507 - accuracy: 0.9815 - val_loss: 0.0685 - val_accuracy: 0.9858 - lr: 0.0010
# Epoch 24/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0384 - accuracy: 0.9886 - val_loss: 0.0605 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 25/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9910
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0290 - accuracy: 0.9910 - val_loss: 0.1306 - val_accuracy: 0.9716 - lr: 0.0010
# Epoch 26/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.0635 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0667 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0755 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 29/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0754 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 30/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9968
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.0757 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 31/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0843 - val_accuracy: 0.9787 - lr: 2.5000e-04
# Epoch 32/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0690 - val_accuracy: 0.9886 - lr: 2.5000e-04
# Epoch 33/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0671 - val_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 34/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0693 - val_accuracy: 0.9886 - lr: 2.5000e-04
# Epoch 35/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9987
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0029 - accuracy: 0.9987 - val_loss: 0.0605 - val_accuracy: 0.9886 - lr: 2.5000e-04
# Epoch 36/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.0618 - val_accuracy: 0.9886 - lr: 1.2500e-04
# Epoch 37/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0632 - val_accuracy: 0.9915 - lr: 1.2500e-04
# Epoch 38/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0650 - val_accuracy: 0.9900 - lr: 1.2500e-04
# Epoch 39/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0742 - val_accuracy: 0.9872 - lr: 1.2500e-04
# Epoch 40/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0707 - val_accuracy: 0.9886 - lr: 1.2500e-04
# Epoch 41/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0647 - val_accuracy: 0.9929 - lr: 6.2500e-05
# Epoch 42/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.0650 - val_accuracy: 0.9929 - lr: 6.2500e-05
# Epoch 43/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0601 - val_accuracy: 0.9943 - lr: 6.2500e-05
# Epoch 44/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0639 - val_accuracy: 0.9915 - lr: 6.2500e-05
# Epoch 45/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9915 - lr: 6.2500e-05
# Epoch 46/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0659 - val_accuracy: 0.9915 - lr: 3.1250e-05
# Epoch 47/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0011 - accuracy: 0.9991 - val_loss: 0.0638 - val_accuracy: 0.9915 - lr: 3.1250e-05
# Epoch 48/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 0.0647 - val_accuracy: 0.9915 - lr: 3.1250e-05
# Epoch 49/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.0646 - val_accuracy: 0.9915 - lr: 3.1250e-05
# Epoch 50/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9992
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 0.0677 - val_accuracy: 0.9915 - lr: 3.1250e-05
# Epoch 51/100
# 198/198 [==============================] - 38s 191ms/step - loss: 9.0741e-04 - accuracy: 0.9995 - val_loss: 0.0683 - val_accuracy: 0.9915 - lr: 1.5625e-05
# Epoch 52/100
# 198/198 [==============================] - 37s 189ms/step - loss: 9.1015e-04 - accuracy: 0.9997 - val_loss: 0.0640 - val_accuracy: 0.9943 - lr: 1.5625e-05
# Epoch 53/100
# 198/198 [==============================] - 37s 189ms/step - loss: 7.9307e-04 - accuracy: 0.9998 - val_loss: 0.0653 - val_accuracy: 0.9915 - lr: 1.5625e-05
# 22/22 [==============================] - 1s 40ms/step
# Accuracy for Fold 1: 0.9943
# Training Fold 2/10
# Found 6320 images belonging to 4 classes.
# Found 703 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - 50s 193ms/step - loss: 0.9385 - accuracy: 0.5848 - val_loss: 1.3412 - val_accuracy: 0.5548 - lr: 0.0010
# Epoch 2/100
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 38s 194ms/step - loss: 0.6035 - accuracy: 0.7528 - val_loss: 0.7907 - val_accuracy: 0.6828 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.4967 - accuracy: 0.8014 - val_loss: 0.4479 - val_accuracy: 0.8193 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.4271 - accuracy: 0.8302 - val_loss: 0.5479 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.3999 - accuracy: 0.8415 - val_loss: 0.4158 - val_accuracy: 0.8464 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.3232 - accuracy: 0.8739 - val_loss: 0.3476 - val_accuracy: 0.8848 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.2633 - accuracy: 0.8964 - val_loss: 0.2567 - val_accuracy: 0.8976 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2236 - accuracy: 0.9152 - val_loss: 0.2389 - val_accuracy: 0.9147 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1778 - accuracy: 0.9329 - val_loss: 0.2919 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1552 - accuracy: 0.9408 - val_loss: 0.1954 - val_accuracy: 0.9260 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1245 - accuracy: 0.9549 - val_loss: 0.2236 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0908 - accuracy: 0.9663 - val_loss: 0.3450 - val_accuracy: 0.8933 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0832 - accuracy: 0.9707 - val_loss: 0.0913 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0651 - accuracy: 0.9758 - val_loss: 0.1191 - val_accuracy: 0.9531 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0803 - accuracy: 0.9733 - val_loss: 0.1108 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0530 - accuracy: 0.9812 - val_loss: 0.0702 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0620 - accuracy: 0.9778 - val_loss: 0.0626 - val_accuracy: 0.9844 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0498 - accuracy: 0.9831 - val_loss: 0.0590 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0368 - accuracy: 0.9872 - val_loss: 0.0806 - val_accuracy: 0.9673 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0358 - accuracy: 0.9886 - val_loss: 0.0762 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0416 - accuracy: 0.9842 - val_loss: 0.1030 - val_accuracy: 0.9716 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0440 - accuracy: 0.9867 - val_loss: 0.0695 - val_accuracy: 0.9730 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9918
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0264 - accuracy: 0.9918 - val_loss: 0.0925 - val_accuracy: 0.9801 - lr: 0.0010
# Epoch 24/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0656 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 25/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0133 - accuracy: 0.9949 - val_loss: 0.0781 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 26/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0473 - val_accuracy: 0.9872 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.0507 - val_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0867 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 29/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.0387 - val_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 30/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0138 - accuracy: 0.9956 - val_loss: 0.0550 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 31/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0845 - val_accuracy: 0.9815 - lr: 5.0000e-04
# Epoch 32/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.1173 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 33/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.1557 - val_accuracy: 0.9730 - lr: 5.0000e-04
# Epoch 34/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9964
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.1132 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 35/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0055 - accuracy: 0.9976 - val_loss: 0.0428 - val_accuracy: 0.9943 - lr: 2.5000e-04
# Epoch 36/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 0.0791 - val_accuracy: 0.9872 - lr: 2.5000e-04
# Epoch 37/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0512 - val_accuracy: 0.9915 - lr: 2.5000e-04
# Epoch 38/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.0843 - val_accuracy: 0.9886 - lr: 2.5000e-04
# Epoch 39/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9972
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0050 - accuracy: 0.9972 - val_loss: 0.0839 - val_accuracy: 0.9829 - lr: 2.5000e-04
# Epoch 40/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0025 - accuracy: 0.9987 - val_loss: 0.0631 - val_accuracy: 0.9886 - lr: 1.2500e-04
# Epoch 41/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0012 - accuracy: 0.9991 - val_loss: 0.0638 - val_accuracy: 0.9872 - lr: 1.2500e-04
# Epoch 42/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0655 - val_accuracy: 0.9900 - lr: 1.2500e-04
# Epoch 43/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.0714 - val_accuracy: 0.9886 - lr: 1.2500e-04
# Epoch 44/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9991
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0629 - val_accuracy: 0.9900 - lr: 1.2500e-04
# Epoch 45/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 0.0633 - val_accuracy: 0.9915 - lr: 6.2500e-05
# 22/22 [==============================] - 1s 38ms/step
# Accuracy for Fold 2: 0.9943
# Training Fold 3/10
# Found 6320 images belonging to 4 classes.
# Found 703 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - 51s 198ms/step - loss: 0.8611 - accuracy: 0.6244 - val_loss: 0.8542 - val_accuracy: 0.6842 - lr: 0.0010
# Epoch 2/100
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 38s 192ms/step - loss: 0.6033 - accuracy: 0.7524 - val_loss: 0.5587 - val_accuracy: 0.7866 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.5145 - accuracy: 0.7843 - val_loss: 0.4371 - val_accuracy: 0.8122 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.4372 - accuracy: 0.8185 - val_loss: 0.6361 - val_accuracy: 0.7752 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.3571 - accuracy: 0.8574 - val_loss: 0.3584 - val_accuracy: 0.8649 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.2940 - accuracy: 0.8845 - val_loss: 0.2964 - val_accuracy: 0.8905 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2495 - accuracy: 0.9085 - val_loss: 0.2191 - val_accuracy: 0.9147 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.1947 - accuracy: 0.9272 - val_loss: 0.1857 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1740 - accuracy: 0.9359 - val_loss: 0.1552 - val_accuracy: 0.9502 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1313 - accuracy: 0.9505 - val_loss: 0.1171 - val_accuracy: 0.9616 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1039 - accuracy: 0.9627 - val_loss: 0.2028 - val_accuracy: 0.9346 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1049 - accuracy: 0.9595 - val_loss: 0.1718 - val_accuracy: 0.9474 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0836 - accuracy: 0.9688 - val_loss: 0.1587 - val_accuracy: 0.9474 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0770 - accuracy: 0.9736 - val_loss: 0.1124 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0514 - accuracy: 0.9826 - val_loss: 0.1330 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0534 - accuracy: 0.9815 - val_loss: 0.2345 - val_accuracy: 0.9360 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0545 - accuracy: 0.9829 - val_loss: 0.1532 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0421 - accuracy: 0.9872 - val_loss: 0.0961 - val_accuracy: 0.9787 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0428 - accuracy: 0.9861 - val_loss: 0.0878 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0427 - accuracy: 0.9858 - val_loss: 0.1155 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0474 - accuracy: 0.9843 - val_loss: 0.1116 - val_accuracy: 0.9716 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0324 - accuracy: 0.9897 - val_loss: 0.1089 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0330 - accuracy: 0.9900 - val_loss: 0.1118 - val_accuracy: 0.9772 - lr: 0.0010
# Epoch 24/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9910
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0252 - accuracy: 0.9910 - val_loss: 0.1006 - val_accuracy: 0.9772 - lr: 0.0010
# Epoch 25/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0983 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 26/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.1067 - val_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0788 - val_accuracy: 0.9872 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.1005 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 29/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.1122 - val_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 30/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.1134 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 31/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0785 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 32/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.1272 - val_accuracy: 0.9758 - lr: 5.0000e-04
# Epoch 33/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.0844 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 34/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.1085 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 35/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.1220 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 36/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1395 - val_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 37/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.1190 - val_accuracy: 0.9844 - lr: 2.5000e-04
# 22/22 [==============================] - 1s 38ms/step
# Accuracy for Fold 3: 0.9872
# Training Fold 4/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - 50s 193ms/step - loss: 0.8413 - accuracy: 0.6247 - val_loss: 0.8470 - val_accuracy: 0.6439 - lr: 0.0010
# Epoch 2/100
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 38s 191ms/step - loss: 0.5777 - accuracy: 0.7573 - val_loss: 0.8082 - val_accuracy: 0.6439 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.4805 - accuracy: 0.8045 - val_loss: 0.4456 - val_accuracy: 0.7749 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.4033 - accuracy: 0.8394 - val_loss: 0.3751 - val_accuracy: 0.8390 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.3518 - accuracy: 0.8595 - val_loss: 0.2650 - val_accuracy: 0.8960 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.2950 - accuracy: 0.8809 - val_loss: 0.2546 - val_accuracy: 0.9046 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.2534 - accuracy: 0.9046 - val_loss: 0.2593 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2242 - accuracy: 0.9154 - val_loss: 0.2035 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1840 - accuracy: 0.9323 - val_loss: 0.2352 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1522 - accuracy: 0.9435 - val_loss: 0.1169 - val_accuracy: 0.9601 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1253 - accuracy: 0.9563 - val_loss: 0.1149 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1082 - accuracy: 0.9586 - val_loss: 0.1447 - val_accuracy: 0.9501 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0904 - accuracy: 0.9693 - val_loss: 0.1477 - val_accuracy: 0.9558 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0894 - accuracy: 0.9680 - val_loss: 0.0845 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0652 - accuracy: 0.9771 - val_loss: 0.1068 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0593 - accuracy: 0.9791 - val_loss: 0.1106 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0628 - accuracy: 0.9785 - val_loss: 0.0575 - val_accuracy: 0.9801 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0567 - accuracy: 0.9818 - val_loss: 0.0708 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0433 - accuracy: 0.9847 - val_loss: 0.1552 - val_accuracy: 0.9459 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0514 - accuracy: 0.9813 - val_loss: 0.1323 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0337 - accuracy: 0.9878 - val_loss: 0.1031 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9888
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0353 - accuracy: 0.9888 - val_loss: 0.0624 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0198 - accuracy: 0.9941 - val_loss: 0.0314 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 24/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.1351 - val_accuracy: 0.9601 - lr: 5.0000e-04
# Epoch 25/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0977 - val_accuracy: 0.9729 - lr: 5.0000e-04
# Epoch 26/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0104 - accuracy: 0.9959 - val_loss: 0.1153 - val_accuracy: 0.9744 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.0533 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9957
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.0445 - val_accuracy: 0.9915 - lr: 5.0000e-04
# Epoch 29/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0566 - val_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 30/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0589 - val_accuracy: 0.9872 - lr: 2.5000e-04
# Epoch 31/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0509 - val_accuracy: 0.9915 - lr: 2.5000e-04
# Epoch 32/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0032 - accuracy: 0.9983 - val_loss: 0.0542 - val_accuracy: 0.9915 - lr: 2.5000e-04
# Epoch 33/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9987
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0664 - val_accuracy: 0.9858 - lr: 2.5000e-04
# Epoch 34/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0726 - val_accuracy: 0.9829 - lr: 1.2500e-04
# Epoch 35/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0867 - val_accuracy: 0.9829 - lr: 1.2500e-04
# Epoch 36/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0028 - accuracy: 0.9987 - val_loss: 0.0790 - val_accuracy: 0.9872 - lr: 1.2500e-04
# Epoch 37/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.0679 - val_accuracy: 0.9872 - lr: 1.2500e-04
# Epoch 38/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9989
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0777 - val_accuracy: 0.9900 - lr: 1.2500e-04
# 22/22 [==============================] - 1s 37ms/step
# Accuracy for Fold 4: 0.9915
# Training Fold 5/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - 49s 187ms/step - loss: 0.9388 - accuracy: 0.5825 - val_loss: 0.6640 - val_accuracy: 0.6895 - lr: 0.0010
# Epoch 2/100
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 37s 186ms/step - loss: 0.6111 - accuracy: 0.7507 - val_loss: 1.2829 - val_accuracy: 0.5840 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.5111 - accuracy: 0.7913 - val_loss: 0.4733 - val_accuracy: 0.7991 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.4603 - accuracy: 0.8143 - val_loss: 0.5608 - val_accuracy: 0.7678 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.3880 - accuracy: 0.8424 - val_loss: 0.7044 - val_accuracy: 0.7379 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.3427 - accuracy: 0.8608 - val_loss: 0.3030 - val_accuracy: 0.8775 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.2990 - accuracy: 0.8826 - val_loss: 0.2843 - val_accuracy: 0.8846 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.2570 - accuracy: 0.8981 - val_loss: 0.1832 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.2151 - accuracy: 0.9206 - val_loss: 0.1768 - val_accuracy: 0.9188 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1888 - accuracy: 0.9309 - val_loss: 0.2040 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.1539 - accuracy: 0.9453 - val_loss: 0.1782 - val_accuracy: 0.9117 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.1415 - accuracy: 0.9492 - val_loss: 0.1429 - val_accuracy: 0.9473 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1101 - accuracy: 0.9606 - val_loss: 0.1191 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.1032 - accuracy: 0.9644 - val_loss: 0.1371 - val_accuracy: 0.9615 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0824 - accuracy: 0.9731 - val_loss: 0.1170 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0673 - accuracy: 0.9775 - val_loss: 0.1005 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0685 - accuracy: 0.9766 - val_loss: 0.1008 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0634 - accuracy: 0.9779 - val_loss: 0.0643 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0585 - accuracy: 0.9798 - val_loss: 0.0473 - val_accuracy: 0.9843 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0404 - accuracy: 0.9858 - val_loss: 0.0794 - val_accuracy: 0.9772 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0444 - accuracy: 0.9861 - val_loss: 0.0740 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.0759 - val_accuracy: 0.9801 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0439 - accuracy: 0.9864 - val_loss: 0.0643 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 24/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9892
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0328 - accuracy: 0.9892 - val_loss: 0.0519 - val_accuracy: 0.9872 - lr: 0.0010
# Epoch 25/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0500 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 26/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 0.0865 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0599 - val_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0161 - accuracy: 0.9946 - val_loss: 0.0592 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 29/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9956
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0167 - accuracy: 0.9956 - val_loss: 0.0495 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 30/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0478 - val_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 31/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0538 - val_accuracy: 0.9858 - lr: 2.5000e-04
# Epoch 32/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.0513 - val_accuracy: 0.9886 - lr: 2.5000e-04
# Epoch 33/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0557 - val_accuracy: 0.9886 - lr: 2.5000e-04
# Epoch 34/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0468 - val_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 35/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0361 - val_accuracy: 0.9929 - lr: 2.5000e-04
# Epoch 36/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0563 - val_accuracy: 0.9829 - lr: 2.5000e-04
# Epoch 37/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0610 - val_accuracy: 0.9829 - lr: 2.5000e-04
# Epoch 38/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0483 - val_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 39/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0037 - accuracy: 0.9983 - val_loss: 0.0408 - val_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 40/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9995
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0410 - val_accuracy: 0.9929 - lr: 2.5000e-04
# Epoch 41/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0569 - val_accuracy: 0.9900 - lr: 1.2500e-04
# Epoch 42/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0013 - accuracy: 0.9991 - val_loss: 0.0478 - val_accuracy: 0.9886 - lr: 1.2500e-04
# Epoch 43/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.0491 - val_accuracy: 0.9915 - lr: 1.2500e-04
# Epoch 44/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0476 - val_accuracy: 0.9915 - lr: 1.2500e-04
# Epoch 45/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0477 - val_accuracy: 0.9900 - lr: 1.2500e-04
# 22/22 [==============================] - 1s 37ms/step
# Accuracy for Fold 5: 0.9929
# Training Fold 6/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - 50s 189ms/step - loss: 0.9035 - accuracy: 0.6084 - val_loss: 1.0784 - val_accuracy: 0.5883 - lr: 0.0010
# Epoch 2/100
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 37s 186ms/step - loss: 0.6093 - accuracy: 0.7409 - val_loss: 0.4767 - val_accuracy: 0.7977 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.4941 - accuracy: 0.7956 - val_loss: 0.6385 - val_accuracy: 0.7792 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.4103 - accuracy: 0.8301 - val_loss: 0.3794 - val_accuracy: 0.8718 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.3634 - accuracy: 0.8562 - val_loss: 0.4115 - val_accuracy: 0.8447 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.3208 - accuracy: 0.8720 - val_loss: 0.2435 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.2762 - accuracy: 0.8905 - val_loss: 0.4443 - val_accuracy: 0.8618 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.2456 - accuracy: 0.9035 - val_loss: 0.3178 - val_accuracy: 0.9031 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.1831 - accuracy: 0.9288 - val_loss: 0.2438 - val_accuracy: 0.9117 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1622 - accuracy: 0.9361 - val_loss: 0.2586 - val_accuracy: 0.9288 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1399 - accuracy: 0.9491 - val_loss: 0.1843 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1039 - accuracy: 0.9627 - val_loss: 0.1694 - val_accuracy: 0.9330 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.1081 - accuracy: 0.9620 - val_loss: 0.1203 - val_accuracy: 0.9615 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0823 - accuracy: 0.9726 - val_loss: 0.1462 - val_accuracy: 0.9530 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0701 - accuracy: 0.9750 - val_loss: 0.1128 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0591 - accuracy: 0.9799 - val_loss: 0.1119 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0582 - accuracy: 0.9790 - val_loss: 0.1090 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0481 - accuracy: 0.9839 - val_loss: 0.1232 - val_accuracy: 0.9601 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0453 - accuracy: 0.9856 - val_loss: 0.0822 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0340 - accuracy: 0.9888 - val_loss: 0.1076 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0464 - accuracy: 0.9870 - val_loss: 0.0587 - val_accuracy: 0.9843 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0446 - accuracy: 0.9856 - val_loss: 0.1097 - val_accuracy: 0.9715 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0442 - accuracy: 0.9862 - val_loss: 0.0812 - val_accuracy: 0.9701 - lr: 0.0010
# Epoch 24/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0359 - accuracy: 0.9888 - val_loss: 0.0530 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 25/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0335 - accuracy: 0.9894 - val_loss: 0.0563 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 26/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0340 - accuracy: 0.9900 - val_loss: 0.1143 - val_accuracy: 0.9601 - lr: 0.0010
# Epoch 27/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0294 - accuracy: 0.9911 - val_loss: 0.1236 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 28/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0351 - accuracy: 0.9875 - val_loss: 0.1397 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 29/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9908
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0258 - accuracy: 0.9908 - val_loss: 0.1356 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 30/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0662 - val_accuracy: 0.9872 - lr: 5.0000e-04
# Epoch 31/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.1030 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 32/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0697 - val_accuracy: 0.9872 - lr: 5.0000e-04
# Epoch 33/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.0741 - val_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 34/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9972
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.1003 - val_accuracy: 0.9815 - lr: 5.0000e-04
# Epoch 35/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0774 - val_accuracy: 0.9872 - lr: 2.5000e-04
# Epoch 36/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0696 - val_accuracy: 0.9886 - lr: 2.5000e-04
# Epoch 37/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0768 - val_accuracy: 0.9829 - lr: 2.5000e-04
# Epoch 38/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0905 - val_accuracy: 0.9843 - lr: 2.5000e-04
# ...
# Epoch 3/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.5061 - accuracy: 0.7863 - val_loss: 0.4091 - val_accuracy: 0.8419 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.4310 - accuracy: 0.8271 - val_loss: 0.3768 - val_accuracy: 0.8632 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.3846 - accuracy: 0.8401 - val_loss: 0.3519 - val_accuracy: 0.8718 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.3095 - accuracy: 0.8766 - val_loss: 0.2618 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.2744 - accuracy: 0.8950 - val_loss: 0.1823 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2280 - accuracy: 0.9146 - val_loss: 0.1804 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1814 - accuracy: 0.9298 - val_loss: 0.1781 - val_accuracy: 0.9402 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1663 - accuracy: 0.9324 - val_loss: 0.1599 - val_accuracy: 0.9544 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1268 - accuracy: 0.9554 - val_loss: 0.1416 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1160 - accuracy: 0.9587 - val_loss: 0.0960 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0892 - accuracy: 0.9685 - val_loss: 0.1040 - val_accuracy: 0.9601 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0847 - accuracy: 0.9707 - val_loss: 0.0669 - val_accuracy: 0.9772 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0777 - accuracy: 0.9714 - val_loss: 0.1044 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0686 - accuracy: 0.9764 - val_loss: 0.1032 - val_accuracy: 0.9601 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0683 - accuracy: 0.9758 - val_loss: 0.0569 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0499 - accuracy: 0.9815 - val_loss: 0.0476 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0456 - accuracy: 0.9853 - val_loss: 0.0513 - val_accuracy: 0.9858 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0514 - accuracy: 0.9848 - val_loss: 0.1321 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0466 - accuracy: 0.9842 - val_loss: 0.0521 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 0.0715 - val_accuracy: 0.9801 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9848
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0437 - accuracy: 0.9848 - val_loss: 0.0489 - val_accuracy: 0.9843 - lr: 0.0010
# Epoch 24/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 0.0439 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 25/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.0387 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 26/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0296 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0134 - accuracy: 0.9949 - val_loss: 0.0222 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.0282 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 29/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0258 - val_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 30/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0113 - accuracy: 0.9975 - val_loss: 0.0216 - val_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 31/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0127 - accuracy: 0.9968 - val_loss: 0.0285 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 32/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0105 - accuracy: 0.9960 - val_loss: 0.0366 - val_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 33/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0158 - accuracy: 0.9943 - val_loss: 0.0299 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 34/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 0.0458 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 35/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.0199 - val_accuracy: 0.9915 - lr: 5.0000e-04
# Epoch 36/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0132 - accuracy: 0.9951 - val_loss: 0.0298 - val_accuracy: 0.9915 - lr: 5.0000e-04
# Epoch 37/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.0198 - val_accuracy: 0.9972 - lr: 5.0000e-04
# Epoch 38/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0166 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 39/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0283 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 40/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.0289 - val_accuracy: 0.9957 - lr: 5.0000e-04
# Epoch 41/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0512 - val_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 42/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0175 - accuracy: 0.9953 - val_loss: 0.0329 - val_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 43/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9967
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0347 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 44/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0239 - val_accuracy: 0.9957 - lr: 2.5000e-04
# Epoch 45/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0325 - val_accuracy: 0.9915 - lr: 2.5000e-04
# Epoch 46/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0040 - accuracy: 0.9981 - val_loss: 0.0271 - val_accuracy: 0.9943 - lr: 2.5000e-04
# Epoch 47/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0242 - val_accuracy: 0.9972 - lr: 2.5000e-04
# 22/22 [==============================] - 1s 37ms/step
# Accuracy for Fold 9: 0.9972
# Training Fold 10/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - 48s 188ms/step - loss: 0.8755 - accuracy: 0.6143 - val_loss: 0.8946 - val_accuracy: 0.6140 - lr: 0.0010
# Epoch 2/100
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 37s 186ms/step - loss: 0.6061 - accuracy: 0.7409 - val_loss: 1.5565 - val_accuracy: 0.5356 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.5237 - accuracy: 0.7738 - val_loss: 0.5315 - val_accuracy: 0.7493 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.4264 - accuracy: 0.8242 - val_loss: 0.4093 - val_accuracy: 0.8504 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.3548 - accuracy: 0.8617 - val_loss: 0.3484 - val_accuracy: 0.8561 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.2709 - accuracy: 0.9003 - val_loss: 0.2816 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.2352 - accuracy: 0.9128 - val_loss: 0.1791 - val_accuracy: 0.9302 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1682 - accuracy: 0.9396 - val_loss: 0.1974 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1552 - accuracy: 0.9432 - val_loss: 0.1852 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1046 - accuracy: 0.9655 - val_loss: 0.1432 - val_accuracy: 0.9558 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0951 - accuracy: 0.9665 - val_loss: 0.1322 - val_accuracy: 0.9558 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0854 - accuracy: 0.9715 - val_loss: 0.1077 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0721 - accuracy: 0.9786 - val_loss: 0.1014 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0707 - accuracy: 0.9758 - val_loss: 0.1031 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0522 - accuracy: 0.9843 - val_loss: 0.0401 - val_accuracy: 0.9843 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0501 - accuracy: 0.9840 - val_loss: 0.0970 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0476 - accuracy: 0.9850 - val_loss: 0.0806 - val_accuracy: 0.9801 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0510 - accuracy: 0.9839 - val_loss: 0.0655 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0390 - accuracy: 0.9867 - val_loss: 0.1091 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0382 - accuracy: 0.9881 - val_loss: 0.0237 - val_accuracy: 0.9900 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0407 - accuracy: 0.9878 - val_loss: 0.0510 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0443 - accuracy: 0.9848 - val_loss: 0.0631 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0323 - accuracy: 0.9894 - val_loss: 0.1385 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 24/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0386 - accuracy: 0.9891 - val_loss: 0.1058 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 25/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9869
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0352 - accuracy: 0.9869 - val_loss: 0.0583 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 26/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0109 - accuracy: 0.9960 - val_loss: 0.0506 - val_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0322 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0144 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 29/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.0383 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 30/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0091 - accuracy: 0.9956 - val_loss: 0.0357 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 31/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0273 - val_accuracy: 0.9886 - lr: 5.0000e-04
# Epoch 32/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0246 - val_accuracy: 0.9915 - lr: 5.0000e-04
# Epoch 33/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9968
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.0419 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 34/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0308 - val_accuracy: 0.9943 - lr: 2.5000e-04
# Epoch 35/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0028 - accuracy: 0.9987 - val_loss: 0.0298 - val_accuracy: 0.9915 - lr: 2.5000e-04
# Epoch 36/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0271 - val_accuracy: 0.9943 - lr: 2.5000e-04
# Epoch 37/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.0307 - val_accuracy: 0.9929 - lr: 2.5000e-04
# Epoch 38/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0342 - val_accuracy: 0.9929 - lr: 2.5000e-04
# Epoch 39/100
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0263 - val_accuracy: 0.9929 - lr: 1.2500e-04
# Epoch 40/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0179 - val_accuracy: 0.9943 - lr: 1.2500e-04
# Epoch 41/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0266 - val_accuracy: 0.9943 - lr: 1.2500e-04
# Epoch 42/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0242 - val_accuracy: 0.9943 - lr: 1.2500e-04
# Epoch 43/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9995
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 198/198 [==============================] - 37s 186ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0280 - val_accuracy: 0.9943 - lr: 1.2500e-04
# Epoch 44/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0264 - val_accuracy: 0.9943 - lr: 6.2500e-05
# 22/22 [==============================] - 1s 37ms/step
# Accuracy for Fold 10: 0.9943

# %% [markdown]
# # 5. Results

# %%
# Create fold metrics DataFrame
fold_metrics = {
    "Fold": list(range(1, len(fold_accuracies) + 1)),
    "Accuracy": fold_accuracies
}
fold_metrics_df = pd.DataFrame(fold_metrics)

# Print the DataFrame in the VS Code terminal
print("\nFold-Wise Metrics:")
print(fold_metrics_df)
# Out:
# Fold-Wise Metrics:
#    Fold  Accuracy
# 0     1  0.994310
# 1     2  0.994310
# 2     3  0.987198
# 3     4  0.991453
# 4     5  0.992877
# 5     6  0.990028
# 6     7  0.991453
# 7     8  0.995726
# 8     9  0.997151
# 9    10  0.994302

# %%
# Summary of Cross-Validation Results
print("\n10-Fold Cross-Validation Results")
print(f"Mean Accuracy: {np.mean(fold_accuracies):.4f}")
print(f"Standard Deviation: {np.std(fold_accuracies):.4f}")
# Out:
# 10-Fold Cross-Validation Results
# Mean Accuracy: 0.9929
# Standard Deviation: 0.0028

# %%
from sklearn.metrics import accuracy_score

# Convert probability predictions into class labels (for accuracy)
all_y_pred_labels = np.argmax(np.array(all_y_pred), axis=1)  # Get class indices
all_y_true = np.array(all_y_true)  # Ensure correct format

# Calculate and print the overall test accuracy
overall_test_accuracy = accuracy_score(all_y_true, all_y_pred_labels)
print(f"\nOverall Test Accuracy: {overall_test_accuracy:.4f}")
# Out:
# Overall Test Accuracy: 0.9929

# %% [markdown]
# ### 5.1 Classification Report

# %%
# Generate the final classification report
print("\nFinal Classification Report:")
class_labels = list(test_generator.class_indices.keys())  # Get class labels
print(classification_report(all_y_true, all_y_pred_labels, target_names=class_labels))
# Out:
# Final Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       1.00      0.99      0.99      1621
#   meningioma       0.99      0.99      0.99      1645
#      notumor       1.00      1.00      1.00      2000
#    pituitary       0.99      0.99      0.99      1757
#
#     accuracy                           0.99      7023
#    macro avg       0.99      0.99      0.99      7023
# weighted avg       0.99      0.99      0.99      7023

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label=f'Fold {fold_idx + 1} Train Accuracy')
plt.plot(history.history['val_accuracy'], label=f'Fold {fold_idx + 1} Validation Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Calculate confusion matrix
cm = confusion_matrix(all_y_true, all_y_pred_labels)


# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap="Blues")  # Optional: Choose a color map
plt.title("HybridCNNViT")
plt.show()

# %%
print("y_pred_prob shape:", y_pred_prob.shape)  # Should be (num_samples, num_classes)
print("y_true shape:", len(y_true))  # Should match num_samples
# Out:
# y_pred_prob shape: (702, 4)
# y_true shape: 702

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Convert true labels to one-hot encoding for multi-class ROC curve
num_classes = len(class_labels)
all_y_true_one_hot = label_binarize(all_y_true, classes=np.arange(num_classes))
all_y_pred_prob = np.array(all_y_pred)  # Ensure predictions are in NumPy array format

# Check shapes
print("all_y_true_one_hot shape:", all_y_true_one_hot.shape)
print("all_y_pred_prob shape:", all_y_pred_prob.shape)

# Initialize dictionaries for ROC curve data
fpr, tpr, roc_auc = {}, {}, {}

# Compute ROC curve and AUC for each class
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(all_y_true_one_hot[:, i], all_y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute macro-average ROC curve and AUC
fpr["macro"], tpr["macro"], _ = roc_curve(all_y_true_one_hot.ravel(), all_y_pred_prob.ravel())
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr["macro"], tpr["macro"], label=f'Macro-Average ROC (AUC = {roc_auc["macro"]:.4f})', color='darkorange', linewidth=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='blue', label='Chance (Random)')

# Plot ROC curve for each class
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_labels[i]} (AUC = {roc_auc[i]:.4f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve (HybridCNNViT)')
plt.legend(loc='lower right')
plt.show()
# Out:
# all_y_true_one_hot shape: (7023, 4)
# all_y_pred_prob shape: (7023, 4)

# %%
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# Collect metrics
# Overall metrics after cross-validation
precision, recall, f1, _ = precision_recall_fscore_support(all_y_true, all_y_pred_labels, average='weighted')
overall_metrics = {
    "Metric": ["Mean", "SD", "Test Accuracy", "Precision", "Recall", "F1-Score"],
    "Value": [
        np.mean(fold_accuracies),
        np.std(fold_accuracies),
        overall_test_accuracy,
        precision,
        recall,
        f1
    ]
}

# Convert to DataFrame
metrics_df = pd.DataFrame(overall_metrics)

# Save metrics to a CSV file
output_dir = "../models/model_logs"
os.makedirs(output_dir, exist_ok=True)  # Ensure the directory exists
metrics_file = os.path.join(output_dir, "1db_kaggle_custom_performance_metrics.csv")
metrics_df.to_csv(metrics_file, index=False)

print(f"Metrics saved to '{metrics_file}'")
# Out:
# Metrics saved to '../models/model_logs/1db_kaggle_custom_performance_metrics.csv'

# %%
df = pd.read_csv(metrics_file)
print(df.head())
# Out:
#           Metric     Value
# 0           Mean  0.992881
# 1             SD  0.002774
# 2  Test Accuracy  0.992881
# 3      Precision  0.992883
# 4         Recall  0.992881

# %%
import random
import matplotlib.image as mpimg

# Set your main directory path
main_dir = original_data_dir  # Change this to your actual dataset directory

# Get the class names (folder names)
classes = [d for d in os.listdir(main_dir) if os.path.isdir(os.path.join(main_dir, d))]

# Define the number of images to display per class
num_images = 5

plt.figure(figsize=(15, 6))

# Loop through each class
for idx, class_name in enumerate(classes):
    class_path = os.path.join(main_dir, class_name)
    
    # Get all image files in the class directory
    images = [f for f in os.listdir(class_path) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    # Randomly select 5 images
    selected_images = random.sample(images, min(num_images, len(images)))
    
    # Display the images
    for j, img_name in enumerate(selected_images):
        img_path = os.path.join(class_path, img_name)
        img = mpimg.imread(img_path)
        
        plt.subplot(len(classes), num_images, idx * num_images + j + 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(class_name if j == 0 else "")
        
plt.tight_layout()
plt.show()
