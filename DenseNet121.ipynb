# %% [markdown]
# - actual - 98.45
# - 32, 64, 128, 256, 256 - Relu - Dense 256 - 128 - 98.36
# - 32, 64, 128, 256, 256 - Relu - Dense 1024 - 98.66
# - 32, 64, 128, 256, 256 - Mish - Dense 1024 - 98.16
# - 32, 64, 128, 256, 256 - Mish - Dense 512 - 98.45
# - 32, 64, 128, 256, 256 - LeakyRelu - Dense 1024 - 98.59
# - 32, 64, 128, 256, 256 - LeakyRelu - AdamW - Dense 1024 - 98.59
# - 32, 64, 128, 256, 256 - LeakyRelu - AdamW - 0.001 - Dense 1024 - 0.5 - 98.90
# - 64, 64, 128, 128 - LeakyRelu - AdamW - 0.001 - Dense 1024 - 0.5 - 99.03
# - 64, 64, 128, 128 - LeakyRelu - AdamW - 0.001 - Dense 512 - 0.5 - 96.38
# - 64, 64, 128, 128 - LeakyRelu - AdamW - 0.001 - Dense 2048 - 0.5 -
# - 64, 64, 128, 128 - relu - AdamW - 0.001 - Dense 512 - No dropout - 98.58
# - 32, 64, 128, 256, 128 - relu - AdamW - 0.001 - Dense 512 - 0.5 - 98.12
# - 32, 64, 128, 256, 256 - LeakyRelu - SGD - Dense 1024 - 82.09
# - 32, 64, 128, 256, 256 - LeakyRelu - Dense 512 - 98.42
# -
# - 32, 64, 128, 256, 256 - hard_swish - Dense 1024 - 98.25
# - 32, 64, 128, 256, 256 - hard_swish - Dense 512 - 98.36
# - 32, 64, 128, 256, 256 - Swish - Dense 2048 - 512 - 97.69
# - 16, 32, 64, 128, 128 - Dense 256 - 128 - *
# - change projection_dim to 64 to 128 -
# - Reduce patch size to 8×8 -

# %% [markdown]
# # 1. Import the Libraries

# %%
import os
import shutil
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dropout, Flatten, Dense, Input, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import StratifiedKFold
# Out:
# 2025-09-26 18:01:10.195225: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-26 18:01:10.195272: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-26 18:01:10.195300: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
print("Available GPUs:", gpus)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # 2. Load Data

# %% [markdown]
# ## 2.1 Without Augmentation

# %%
# Paths
original_data_dir = "../data/external/1. Brain Tumor MRI Dataset(Kaggle)"  # Path to the original dataset
split_data_dir = "/split/BT/splitCV5"  # Directory to store split datasets
if not os.path.exists(split_data_dir):
    os.makedirs(split_data_dir)

# Function to clear directories
def clear_directory(directory):
    if os.path.exists(directory):
        shutil.rmtree(directory)  # Remove the entire directory
    os.makedirs(directory, exist_ok=True)  # Recreate the directory

# Clear train, val, and test directories before splitting data
clear_directory(split_data_dir)

# Function to split the dataset into 10 folds and store them in `splitSSWE`
def prepare_splits(data_dir, split_dir, n_splits=10):
    if not os.path.exists(split_dir):
        os.makedirs(split_dir)

    # Get class names (only directories)
    class_names = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
    all_images = []

    # Collect all image paths and labels
    for label, class_name in enumerate(class_names):  # label is an integer index
        class_dir = os.path.join(data_dir, class_name)
        for img_file in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_file)
            if os.path.isfile(img_path):  # Ensure it's a file, not a directory or system file
                all_images.append((img_path, int(label)))  # Store integer label

    all_images = np.array(all_images, dtype=object)  # Ensure proper dtype for mixed types
    #np.random.shuffle(all_images)

    # Create KFold splits
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    fold_idx = 0
    for train_idx, test_idx in kf.split(all_images):
        fold_dir = os.path.join(split_dir, f"fold_{fold_idx}")
        os.makedirs(fold_dir, exist_ok=True)
        train_dir = os.path.join(fold_dir, "train")
        test_dir = os.path.join(fold_dir, "test")
        os.makedirs(train_dir, exist_ok=True)
        os.makedirs(test_dir, exist_ok=True)

        # Copy training data
        for idx in train_idx:
            src, label = all_images[idx]
            class_name = class_names[label]  # Map integer label back to class name
            dest_dir = os.path.join(train_dir, class_name)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(src, dest_dir)

        # Copy testing data
        for idx in test_idx:
            src, label = all_images[idx]
            class_name = class_names[label]  # Map integer label back to class name
            dest_dir = os.path.join(test_dir, class_name)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(src, dest_dir)

        fold_idx += 1


# Prepare splits (only needed once)
prepare_splits(original_data_dir, split_data_dir)

# %% [markdown]
# # 3. Initialize the Model

# %%
from tensorflow.keras import layers, models, applications

def create_model():
    base_model = applications.DenseNet121(
        include_top=False,
        weights='imagenet',
        input_shape=(168, 168, 3),
        pooling=None
    )
    
    model = models.Sequential(name="ResNet50_CNN")
    model.add(base_model)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(1024))
    model.add(layers.LeakyReLU(alpha=0.01))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4, activation='softmax'))
    return model

model = create_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# Model: "ResNet50_CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 5, 5, 1024)        7037504
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1049600
#
#  leaky_re_lu (LeakyReLU)     (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 8091204 (30.87 MB)
# Trainable params: 8007556 (30.55 MB)
# Non-trainable params: 83648 (326.75 KB)
# _________________________________________________________________

# %% [markdown]
# # 4. Model Training - Cross Fold Validation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomContrast, RandomZoom, RandomTranslation
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Perform 10-fold cross-validation
n_splits = 10
all_y_true = []  # To store true labels from all folds
all_y_pred = []  # To store predictions from all folds
fold_accuracies = []

for fold_idx in range(n_splits):
    print(f"Training Fold {fold_idx + 1}/{n_splits}")
    fold_dir = os.path.join(split_data_dir, f"fold_{fold_idx}")

    train_dir = os.path.join(fold_dir, "train")
    test_dir = os.path.join(fold_dir, "test")

    # Image Data Generators for train and test
    train_datagen = ImageDataGenerator(
        rescale=1.0/255.0,
        # Add custom augmentations here
        horizontal_flip=True,
        rotation_range=2,  # Random rotation within 2 degrees
        brightness_range=[0.8, 1.2],  # Random contrast (brightness scaling)
        zoom_range=[0.95, 1.05],  # Random zoom between 95% and 105%
        width_shift_range=0.01,  # Random horizontal shift
        height_shift_range=0.01,  # Random vertical shift
    )

    test_datagen = ImageDataGenerator(rescale=1.0/255.0)

    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(168, 168),
        batch_size=32,
        class_mode='categorical'
    )
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(168, 168),
        batch_size=32,
        class_mode='categorical',
        shuffle=False
    )

    # Create the model
    # model = hybrid_cnn_vit(input_shape=(224,224,3), num_classes=4)
    model = create_model()

    # ✅ Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-5),
        loss='categorical_crossentropy',  # use 'sparse_categorical_crossentropy' if labels are integers
        metrics=['accuracy']
    )

    # Define callbacks
    callbacks = [
        EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),
        ModelCheckpoint(filepath=os.path.join(split_data_dir, f"best_model_fold_{fold_idx}.h5"), save_best_only=True)
    ]
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

    # Train the model
    history = model.fit(
        train_generator,
        epochs=100,
        validation_data=test_generator,
        callbacks=[callbacks, lr_scheduler]
    )

    # Predict on the test set
    test_generator.reset()
    y_pred_prob = model.predict(test_generator)  # Get probabilities or logits
    y_pred = np.argmax(y_pred_prob, axis=1)  # Get the predicted class indices
    y_true = test_generator.classes  # True labels

    # Collect results for final classification report
    all_y_true.extend(y_true)
    all_y_pred.extend(y_pred_prob)

    # Calculate and store fold accuracy
    accuracy = accuracy_score(y_true, y_pred)
    fold_accuracies.append(accuracy)
    print(f"Accuracy for Fold {fold_idx + 1}: {accuracy:.4f}")
# Out:
# Training Fold 1/10
# Found 6320 images belonging to 4 classes.
# Found 703 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8595
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 96s 231ms/step - loss: 0.4324 - accuracy: 0.8595 - val_loss: 1.6939 - val_accuracy: 0.6871 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.2284 - accuracy: 0.9239 - val_loss: 1.3544 - val_accuracy: 0.7368 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.1978 - accuracy: 0.9335 - val_loss: 0.7359 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.1363 - accuracy: 0.9528 - val_loss: 0.6998 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 39s 199ms/step - loss: 0.1371 - accuracy: 0.9566 - val_loss: 0.4861 - val_accuracy: 0.8819 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.1202 - accuracy: 0.9600 - val_loss: 0.3748 - val_accuracy: 0.8862 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1042 - accuracy: 0.9649 - val_loss: 3.2260 - val_accuracy: 0.5733 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 39s 197ms/step - loss: 0.1276 - accuracy: 0.9585 - val_loss: 0.2504 - val_accuracy: 0.9260 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.0914 - accuracy: 0.9693 - val_loss: 0.2236 - val_accuracy: 0.9061 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0679 - accuracy: 0.9786 - val_loss: 0.2509 - val_accuracy: 0.9346 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1602 - accuracy: 0.9543 - val_loss: 20162.5996 - val_accuracy: 0.2745 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2895 - accuracy: 0.9222 - val_loss: 0.3376 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 39s 194ms/step - loss: 0.1157 - accuracy: 0.9604 - val_loss: 0.0956 - val_accuracy: 0.9616 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0709 - accuracy: 0.9764 - val_loss: 0.3475 - val_accuracy: 0.8905 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0642 - accuracy: 0.9782 - val_loss: 0.2736 - val_accuracy: 0.9218 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.0628 - accuracy: 0.9793 - val_loss: 0.0731 - val_accuracy: 0.9772 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0877 - accuracy: 0.9753 - val_loss: 0.3277 - val_accuracy: 0.8862 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0578 - accuracy: 0.9835 - val_loss: 0.4500 - val_accuracy: 0.9104 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0496 - accuracy: 0.9853 - val_loss: 0.1175 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0400 - accuracy: 0.9878 - val_loss: 0.1155 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9831
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0510 - accuracy: 0.9831 - val_loss: 0.0877 - val_accuracy: 0.9772 - lr: 0.0010
# 22/22 [==============================] - 2s 45ms/step
# Accuracy for Fold 1: 0.9772
# Training Fold 2/10
# Found 6320 images belonging to 4 classes.
# Found 703 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4336 - accuracy: 0.8559
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 83s 210ms/step - loss: 0.4336 - accuracy: 0.8559 - val_loss: 12.6144 - val_accuracy: 0.3514 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.2395 - accuracy: 0.9198 - val_loss: 0.3309 - val_accuracy: 0.8905 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1690 - accuracy: 0.9470 - val_loss: 0.7048 - val_accuracy: 0.8293 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1381 - accuracy: 0.9522 - val_loss: 70.6094 - val_accuracy: 0.2987 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 39s 197ms/step - loss: 0.1544 - accuracy: 0.9479 - val_loss: 0.1569 - val_accuracy: 0.9431 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1102 - accuracy: 0.9646 - val_loss: 0.1903 - val_accuracy: 0.9417 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1112 - accuracy: 0.9609 - val_loss: 3.3946 - val_accuracy: 0.4111 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0947 - accuracy: 0.9696 - val_loss: 1.3718 - val_accuracy: 0.6984 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0840 - accuracy: 0.9739 - val_loss: 2.4179 - val_accuracy: 0.7255 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9555
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1550 - accuracy: 0.9555 - val_loss: 31473338.0000 - val_accuracy: 0.2930 - lr: 0.0010
# 22/22 [==============================] - 2s 42ms/step
# Accuracy for Fold 2: 0.9431
# Training Fold 3/10
# Found 6320 images belonging to 4 classes.
# Found 703 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4293 - accuracy: 0.8581
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 84s 212ms/step - loss: 0.4293 - accuracy: 0.8581 - val_loss: 0.3901 - val_accuracy: 0.9004 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2003 - accuracy: 0.9318 - val_loss: 1.0594 - val_accuracy: 0.7027 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1509 - accuracy: 0.9509 - val_loss: 0.4638 - val_accuracy: 0.8492 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.1390 - accuracy: 0.9525 - val_loss: 0.7202 - val_accuracy: 0.7354 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1576 - accuracy: 0.9470 - val_loss: 0.8203 - val_accuracy: 0.8037 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9585
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1231 - accuracy: 0.9585 - val_loss: 0.5893 - val_accuracy: 0.8236 - lr: 0.0010
# 22/22 [==============================] - 2s 51ms/step
# Accuracy for Fold 3: 0.9004
# Training Fold 4/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.8432
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 91s 237ms/step - loss: 0.4919 - accuracy: 0.8432 - val_loss: 173.2131 - val_accuracy: 0.2792 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 39s 197ms/step - loss: 0.2235 - accuracy: 0.9226 - val_loss: 0.7499 - val_accuracy: 0.7550 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.1839 - accuracy: 0.9359 - val_loss: 0.3903 - val_accuracy: 0.8561 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1475 - accuracy: 0.9510 - val_loss: 1.6976 - val_accuracy: 0.7066 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1221 - accuracy: 0.9584 - val_loss: 0.4265 - val_accuracy: 0.9160 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.2228 - accuracy: 0.9294 - val_loss: 0.1252 - val_accuracy: 0.9516 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 39s 199ms/step - loss: 0.1356 - accuracy: 0.9562 - val_loss: 0.1244 - val_accuracy: 0.9558 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0966 - accuracy: 0.9650 - val_loss: 0.4814 - val_accuracy: 0.9302 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0851 - accuracy: 0.9731 - val_loss: 0.1913 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0804 - accuracy: 0.9733 - val_loss: 0.1941 - val_accuracy: 0.9302 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 40s 199ms/step - loss: 0.0760 - accuracy: 0.9739 - val_loss: 0.1060 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0868 - accuracy: 0.9710 - val_loss: 0.4180 - val_accuracy: 0.8903 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.2941 - accuracy: 0.9079 - val_loss: 449.7935 - val_accuracy: 0.2877 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.3399 - accuracy: 0.8934 - val_loss: 0.2696 - val_accuracy: 0.9031 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.1537 - accuracy: 0.9486 - val_loss: 0.3351 - val_accuracy: 0.8860 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.1074 - accuracy: 0.9657 - val_loss: 0.0738 - val_accuracy: 0.9715 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0878 - accuracy: 0.9710 - val_loss: 0.3584 - val_accuracy: 0.8974 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0723 - accuracy: 0.9750 - val_loss: 0.1761 - val_accuracy: 0.9516 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0691 - accuracy: 0.9793 - val_loss: 0.2809 - val_accuracy: 0.9046 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0552 - accuracy: 0.9799 - val_loss: 0.4597 - val_accuracy: 0.8661 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9816
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0611 - accuracy: 0.9816 - val_loss: 0.3904 - val_accuracy: 0.9031 - lr: 0.0010
# 22/22 [==============================] - 2s 40ms/step
# Accuracy for Fold 4: 0.9715
# Training Fold 5/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4423 - accuracy: 0.8545
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 85s 213ms/step - loss: 0.4423 - accuracy: 0.8545 - val_loss: 1.5074 - val_accuracy: 0.6567 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 39s 197ms/step - loss: 0.2392 - accuracy: 0.9166 - val_loss: 1.3109 - val_accuracy: 0.6652 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.1981 - accuracy: 0.9340 - val_loss: 0.8707 - val_accuracy: 0.8162 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.1401 - accuracy: 0.9552 - val_loss: 1.6766 - val_accuracy: 0.7621 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.1452 - accuracy: 0.9495 - val_loss: 0.5195 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.1129 - accuracy: 0.9639 - val_loss: 0.2867 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1463 - accuracy: 0.9581 - val_loss: 10.7233 - val_accuracy: 0.4459 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1129 - accuracy: 0.9617 - val_loss: 0.5651 - val_accuracy: 0.8504 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1877 - accuracy: 0.9410 - val_loss: 1.2391 - val_accuracy: 0.7009 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.1239 - accuracy: 0.9620 - val_loss: 0.2684 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 39s 194ms/step - loss: 0.0858 - accuracy: 0.9742 - val_loss: 0.2600 - val_accuracy: 0.9145 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 39s 197ms/step - loss: 0.0603 - accuracy: 0.9799 - val_loss: 0.2532 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0560 - accuracy: 0.9813 - val_loss: 0.3952 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.0455 - accuracy: 0.9842 - val_loss: 0.1396 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0824 - accuracy: 0.9747 - val_loss: 0.8904 - val_accuracy: 0.7735 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0762 - accuracy: 0.9741 - val_loss: 1.8177 - val_accuracy: 0.8704 - lr: 0.0010
# Epoch 17/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.0750 - accuracy: 0.9755 - val_loss: 0.1327 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 18/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0584 - accuracy: 0.9815 - val_loss: 0.3916 - val_accuracy: 0.9430 - lr: 0.0010
# Epoch 19/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0644 - accuracy: 0.9791 - val_loss: 0.1502 - val_accuracy: 0.9715 - lr: 0.0010
# Epoch 20/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1126 - accuracy: 0.9654 - val_loss: 3.3814 - val_accuracy: 0.8020 - lr: 0.0010
# Epoch 21/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.2851 - accuracy: 0.9312 - val_loss: 37.0454 - val_accuracy: 0.4046 - lr: 0.0010
# Epoch 22/100
# 198/198 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.9272
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 191ms/step - loss: 0.2339 - accuracy: 0.9272 - val_loss: 0.2415 - val_accuracy: 0.9188 - lr: 0.0010
# Epoch 23/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.1370 - accuracy: 0.9616 - val_loss: 0.0496 - val_accuracy: 0.9858 - lr: 5.0000e-04
# Epoch 24/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0767 - accuracy: 0.9788 - val_loss: 0.0669 - val_accuracy: 0.9815 - lr: 5.0000e-04
# Epoch 25/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0608 - accuracy: 0.9861 - val_loss: 2.6292 - val_accuracy: 0.8974 - lr: 5.0000e-04
# Epoch 26/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0631 - accuracy: 0.9820 - val_loss: 0.1329 - val_accuracy: 0.9644 - lr: 5.0000e-04
# Epoch 27/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0276 - accuracy: 0.9899 - val_loss: 0.0694 - val_accuracy: 0.9815 - lr: 5.0000e-04
# Epoch 28/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9899
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0266 - accuracy: 0.9899 - val_loss: 0.0610 - val_accuracy: 0.9858 - lr: 5.0000e-04
# 22/22 [==============================] - 2s 40ms/step
# Accuracy for Fold 5: 0.9858
# Training Fold 6/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4323 - accuracy: 0.8532
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 83s 206ms/step - loss: 0.4323 - accuracy: 0.8532 - val_loss: 5.0914 - val_accuracy: 0.4031 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.2775 - accuracy: 0.9086 - val_loss: 3.2403 - val_accuracy: 0.5142 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.1800 - accuracy: 0.9400 - val_loss: 0.7026 - val_accuracy: 0.8205 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.1492 - accuracy: 0.9497 - val_loss: 0.2809 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1193 - accuracy: 0.9630 - val_loss: 0.4828 - val_accuracy: 0.8319 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1409 - accuracy: 0.9538 - val_loss: 1.6652 - val_accuracy: 0.7507 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1208 - accuracy: 0.9622 - val_loss: 0.3005 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.3730 - accuracy: 0.9014 - val_loss: 15.9829 - val_accuracy: 0.5726 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - ETA: 0s - loss: 0.1594 - accuracy: 0.9513
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 192ms/step - loss: 0.1594 - accuracy: 0.9513 - val_loss: 72079.7188 - val_accuracy: 0.3006 - lr: 0.0010
# 22/22 [==============================] - 2s 41ms/step
# Accuracy for Fold 6: 0.9060
# Training Fold 7/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4222 - accuracy: 0.8611
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 84s 216ms/step - loss: 0.4222 - accuracy: 0.8611 - val_loss: 1.3719 - val_accuracy: 0.7094 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 40s 200ms/step - loss: 0.2312 - accuracy: 0.9275 - val_loss: 1.1133 - val_accuracy: 0.7436 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1478 - accuracy: 0.9487 - val_loss: 16.9439 - val_accuracy: 0.3433 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.1728 - accuracy: 0.9430 - val_loss: 0.4262 - val_accuracy: 0.9031 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1249 - accuracy: 0.9608 - val_loss: 1.8045 - val_accuracy: 0.7279 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.1028 - accuracy: 0.9669 - val_loss: 0.0919 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1332 - accuracy: 0.9582 - val_loss: 0.1242 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.1076 - accuracy: 0.9641 - val_loss: 0.9449 - val_accuracy: 0.8419 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.0902 - accuracy: 0.9687 - val_loss: 0.1481 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1226 - accuracy: 0.9622 - val_loss: 0.7643 - val_accuracy: 0.8689 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9736
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0860 - accuracy: 0.9736 - val_loss: 0.6824 - val_accuracy: 0.8219 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.0390 - accuracy: 0.9889 - val_loss: 0.0358 - val_accuracy: 0.9915 - lr: 5.0000e-04
# Epoch 13/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0224 - accuracy: 0.9941 - val_loss: 0.0517 - val_accuracy: 0.9843 - lr: 5.0000e-04
# Epoch 14/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.0257 - accuracy: 0.9913 - val_loss: 0.0839 - val_accuracy: 0.9630 - lr: 5.0000e-04
# Epoch 15/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.2002 - val_accuracy: 0.9558 - lr: 5.0000e-04
# Epoch 16/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0459 - val_accuracy: 0.9929 - lr: 5.0000e-04
# Epoch 17/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9891
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0349 - accuracy: 0.9891 - val_loss: 0.2077 - val_accuracy: 0.9601 - lr: 5.0000e-04
# Epoch 18/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.0174 - accuracy: 0.9945 - val_loss: 0.0329 - val_accuracy: 0.9872 - lr: 2.5000e-04
# Epoch 19/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0263 - val_accuracy: 0.9929 - lr: 2.5000e-04
# Epoch 20/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.0431 - val_accuracy: 0.9872 - lr: 2.5000e-04
# Epoch 21/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.0089 - accuracy: 0.9983 - val_loss: 0.0222 - val_accuracy: 0.9915 - lr: 2.5000e-04
# 22/22 [==============================] - 2s 40ms/step
# Accuracy for Fold 7: 0.9929
# Training Fold 8/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.8556
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 83s 210ms/step - loss: 0.4202 - accuracy: 0.8556 - val_loss: 0.5128 - val_accuracy: 0.8618 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.2322 - accuracy: 0.9207 - val_loss: 0.6790 - val_accuracy: 0.8889 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.2203 - accuracy: 0.9277 - val_loss: 27.6466 - val_accuracy: 0.2222 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.3427 - accuracy: 0.8919 - val_loss: 0.3473 - val_accuracy: 0.8889 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1452 - accuracy: 0.9489 - val_loss: 0.5316 - val_accuracy: 0.8704 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 39s 194ms/step - loss: 0.1363 - accuracy: 0.9562 - val_loss: 0.0778 - val_accuracy: 0.9715 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1274 - accuracy: 0.9608 - val_loss: 0.0997 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1387 - accuracy: 0.9589 - val_loss: 1.8549 - val_accuracy: 0.6852 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1133 - accuracy: 0.9627 - val_loss: 2.3937 - val_accuracy: 0.4943 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1069 - accuracy: 0.9660 - val_loss: 0.3253 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9723
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0946 - accuracy: 0.9723 - val_loss: 0.1590 - val_accuracy: 0.9516 - lr: 0.0010
# 22/22 [==============================] - 2s 40ms/step
# Accuracy for Fold 8: 0.9715
# Training Fold 9/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.8581
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 84s 205ms/step - loss: 0.4253 - accuracy: 0.8581 - val_loss: 1.1146 - val_accuracy: 0.7621 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.2312 - accuracy: 0.9209 - val_loss: 0.6921 - val_accuracy: 0.7792 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.1712 - accuracy: 0.9402 - val_loss: 0.6325 - val_accuracy: 0.8803 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 39s 196ms/step - loss: 0.1413 - accuracy: 0.9548 - val_loss: 0.1818 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.1369 - accuracy: 0.9562 - val_loss: 1.9369 - val_accuracy: 0.7066 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.1636 - accuracy: 0.9503 - val_loss: 13.7271 - val_accuracy: 0.4487 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.1866 - accuracy: 0.9385 - val_loss: 0.2455 - val_accuracy: 0.9302 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.1121 - accuracy: 0.9635 - val_loss: 0.1143 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 39s 198ms/step - loss: 0.0941 - accuracy: 0.9679 - val_loss: 0.0992 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0664 - accuracy: 0.9782 - val_loss: 0.1204 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.3255 - accuracy: 0.9070 - val_loss: 1.4327 - val_accuracy: 0.6610 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.1505 - accuracy: 0.9517 - val_loss: 0.0661 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0859 - accuracy: 0.9731 - val_loss: 0.1605 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 38s 190ms/step - loss: 0.0694 - accuracy: 0.9771 - val_loss: 0.2310 - val_accuracy: 0.9274 - lr: 0.0010
# 22/22 [==============================] - 2s 40ms/step
# Accuracy for Fold 9: 0.9758
# Training Fold 10/10
# Found 6321 images belonging to 4 classes.
# Found 702 images belonging to 4 classes.
# Epoch 1/100
# 198/198 [==============================] - ETA: 0s - loss: 0.4315 - accuracy: 0.8538
# /home/mc1836@students.ad.unt.edu/miniconda3/envs/bt/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 198/198 [==============================] - 84s 206ms/step - loss: 0.4315 - accuracy: 0.8538 - val_loss: 108.5158 - val_accuracy: 0.3305 - lr: 0.0010
# Epoch 2/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.2210 - accuracy: 0.9256 - val_loss: 0.3676 - val_accuracy: 0.8704 - lr: 0.0010
# Epoch 3/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.1798 - accuracy: 0.9402 - val_loss: 0.6355 - val_accuracy: 0.8148 - lr: 0.0010
# Epoch 4/100
# 198/198 [==============================] - 38s 191ms/step - loss: 0.1713 - accuracy: 0.9419 - val_loss: 0.9519 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 5/100
# 198/198 [==============================] - 38s 192ms/step - loss: 0.2137 - accuracy: 0.9302 - val_loss: 0.2898 - val_accuracy: 0.9145 - lr: 0.0010
# Epoch 6/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.1207 - accuracy: 0.9597 - val_loss: 0.3074 - val_accuracy: 0.9046 - lr: 0.0010
# Epoch 7/100
# 198/198 [==============================] - 38s 189ms/step - loss: 0.0884 - accuracy: 0.9699 - val_loss: 1.7850 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 8/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.1585 - accuracy: 0.9538 - val_loss: 0.2073 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 9/100
# 198/198 [==============================] - 39s 195ms/step - loss: 0.1006 - accuracy: 0.9660 - val_loss: 0.1628 - val_accuracy: 0.9416 - lr: 0.0010
# Epoch 10/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0730 - accuracy: 0.9783 - val_loss: 3.1035 - val_accuracy: 0.5812 - lr: 0.0010
# Epoch 11/100
# 198/198 [==============================] - 38s 193ms/step - loss: 0.0985 - accuracy: 0.9695 - val_loss: 0.0887 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 12/100
# 198/198 [==============================] - 38s 194ms/step - loss: 0.0779 - accuracy: 0.9750 - val_loss: 0.0828 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 13/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0526 - accuracy: 0.9834 - val_loss: 0.2028 - val_accuracy: 0.9387 - lr: 0.0010
# Epoch 14/100
# 198/198 [==============================] - 37s 188ms/step - loss: 0.0671 - accuracy: 0.9799 - val_loss: 0.4056 - val_accuracy: 0.8832 - lr: 0.0010
# Epoch 15/100
# 198/198 [==============================] - 37s 187ms/step - loss: 0.0944 - accuracy: 0.9707 - val_loss: 0.1881 - val_accuracy: 0.9416 - lr: 0.0010
# Epoch 16/100
# 198/198 [==============================] - 37s 189ms/step - loss: 0.0973 - accuracy: 0.9707 - val_loss: 0.8024 - val_accuracy: 0.8276 - lr: 0.0010
# 22/22 [==============================] - 2s 40ms/step
# Accuracy for Fold 10: 0.9729

# %% [markdown]
# # 5. Results

# %%
# Create fold metrics DataFrame
fold_metrics = {
    "Fold": list(range(1, len(fold_accuracies) + 1)),
    "Accuracy": fold_accuracies
}
fold_metrics_df = pd.DataFrame(fold_metrics)

# Print the DataFrame in the VS Code terminal
print("\nFold-Wise Metrics:")
print(fold_metrics_df)
# Out:
# Fold-Wise Metrics:
#    Fold  Accuracy
# 0     1  0.977240
# 1     2  0.943101
# 2     3  0.900427
# 3     4  0.971510
# 4     5  0.985755
# 5     6  0.905983
# 6     7  0.992877
# 7     8  0.971510
# 8     9  0.975783
# 9    10  0.972934

# %%
# Summary of Cross-Validation Results
print("\n10-Fold Cross-Validation Results")
print(f"Mean Accuracy: {np.mean(fold_accuracies):.4f}")
print(f"Standard Deviation: {np.std(fold_accuracies):.4f}")
# Out:
# 10-Fold Cross-Validation Results
# Mean Accuracy: 0.9597
# Standard Deviation: 0.0308

# %%
from sklearn.metrics import accuracy_score

# Convert probability predictions into class labels (for accuracy)
all_y_pred_labels = np.argmax(np.array(all_y_pred), axis=1)  # Get class indices
all_y_true = np.array(all_y_true)  # Ensure correct format

# Calculate and print the overall test accuracy
overall_test_accuracy = accuracy_score(all_y_true, all_y_pred_labels)
print(f"\nOverall Test Accuracy: {overall_test_accuracy:.4f}")
# Out:
# Overall Test Accuracy: 0.9597

# %% [markdown]
# ### 5.1 Classification Report

# %%
# Generate the final classification report
print("\nFinal Classification Report:")
class_labels = list(test_generator.class_indices.keys())  # Get class labels
print(classification_report(all_y_true, all_y_pred_labels, target_names=class_labels))
# Out:
# Final Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       0.97      0.95      0.96      1621
#   meningioma       0.95      0.92      0.93      1645
#      notumor       0.98      0.98      0.98      2000
#    pituitary       0.94      0.99      0.96      1757
#
#     accuracy                           0.96      7023
#    macro avg       0.96      0.96      0.96      7023
# weighted avg       0.96      0.96      0.96      7023

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label=f'Fold {fold_idx + 1} Train Accuracy')
plt.plot(history.history['val_accuracy'], label=f'Fold {fold_idx + 1} Validation Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Calculate confusion matrix
cm = confusion_matrix(all_y_true, all_y_pred_labels)


# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap="Blues")  # Optional: Choose a color map
plt.title("DenseNet121")
plt.show()

# %%
print("y_pred_prob shape:", y_pred_prob.shape)  # Should be (num_samples, num_classes)
print("y_true shape:", len(y_true))  # Should match num_samples
# Out:
# y_pred_prob shape: (702, 4)
# y_true shape: 702

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Convert true labels to one-hot encoding for multi-class ROC curve
num_classes = len(class_labels)
all_y_true_one_hot = label_binarize(all_y_true, classes=np.arange(num_classes))
all_y_pred_prob = np.array(all_y_pred)  # Ensure predictions are in NumPy array format

# Check shapes
print("all_y_true_one_hot shape:", all_y_true_one_hot.shape)
print("all_y_pred_prob shape:", all_y_pred_prob.shape)

# Initialize dictionaries for ROC curve data
fpr, tpr, roc_auc = {}, {}, {}

# Compute ROC curve and AUC for each class
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(all_y_true_one_hot[:, i], all_y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute macro-average ROC curve and AUC
fpr["macro"], tpr["macro"], _ = roc_curve(all_y_true_one_hot.ravel(), all_y_pred_prob.ravel())
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr["macro"], tpr["macro"], label=f'Macro-Average ROC (AUC = {roc_auc["macro"]:.4f})', color='darkorange', linewidth=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='blue', label='Chance (Random)')

# Plot ROC curve for each class
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_labels[i]} (AUC = {roc_auc[i]:.4f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve (DenseNet121)')
plt.legend(loc='lower right')
plt.show()
# Out:
# all_y_true_one_hot shape: (7023, 4)
# all_y_pred_prob shape: (7023, 4)

# %%
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# Collect metrics
# Overall metrics after cross-validation
precision, recall, f1, _ = precision_recall_fscore_support(all_y_true, all_y_pred_labels, average='weighted')
overall_metrics = {
    "Metric": ["Mean", "SD", "Test Accuracy", "Precision", "Recall", "F1-Score"],
    "Value": [
        np.mean(fold_accuracies),
        np.std(fold_accuracies),
        overall_test_accuracy,
        precision,
        recall,
        f1
    ]
}

# Convert to DataFrame
metrics_df = pd.DataFrame(overall_metrics)

# Save metrics to a CSV file
output_dir = "../models/model_logs"
os.makedirs(output_dir, exist_ok=True)  # Ensure the directory exists
metrics_file = os.path.join(output_dir, "1db_kaggle_custom_performance_metrics.csv")
metrics_df.to_csv(metrics_file, index=False)

print(f"Metrics saved to '{metrics_file}'")
# Out:
# Metrics saved to '../models/model_logs/1db_kaggle_custom_performance_metrics.csv'

# %%
df = pd.read_csv(metrics_file)
print(df.head())
# Out:
#           Metric     Value
# 0           Mean  0.959712
# 1             SD  0.030781
# 2  Test Accuracy  0.959704
# 3      Precision  0.959900
# 4         Recall  0.959704

# %%
import random
import matplotlib.image as mpimg

# Set your main directory path
main_dir = original_data_dir  # Change this to your actual dataset directory

# Get the class names (folder names)
classes = [d for d in os.listdir(main_dir) if os.path.isdir(os.path.join(main_dir, d))]

# Define the number of images to display per class
num_images = 5

plt.figure(figsize=(15, 6))

# Loop through each class
for idx, class_name in enumerate(classes):
    class_path = os.path.join(main_dir, class_name)
    
    # Get all image files in the class directory
    images = [f for f in os.listdir(class_path) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    # Randomly select 5 images
    selected_images = random.sample(images, min(num_images, len(images)))
    
    # Display the images
    for j, img_name in enumerate(selected_images):
        img_path = os.path.join(class_path, img_name)
        img = mpimg.imread(img_path)
        
        plt.subplot(len(classes), num_images, idx * num_images + j + 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(class_name if j == 0 else "")
        
plt.tight_layout()
plt.show()
